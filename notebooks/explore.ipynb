# %% [markdown]
# # SonicSightDino: DINOv2-Guided Audio-Visual Source Separation
# Exploratory notebook for visualizing spectrograms, attention maps, and metrics.

# %%
import torch
import matplotlib.pyplot as plt
from src.audio.spectrogram import STFTModule
from src.visual.dinov2 import DINOv2FeatureExtractor
